# %% [markdown]
# <a href="https://colab.research.google.com/github/michalwrona01/IrisAI/blob/main/Iris_BackProp_with_Momentum_Optim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from torch import optim

# %% [markdown]
# **Show dataset**

# %%
iris_show = datasets.load_iris(as_frame=True)
iris_show.data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
iris = datasets.load_iris()
iris_data = iris.data
iris_target = iris.target
iris_labels = iris.target_names

# %% [markdown]
# **Neural Network Model**

# %%
class NNIris(nn.Module):
  def __init__(self, input_layers_size, hidden1_layers_size, hidden2_layers_size, output_layers_size):
    super(NNIris, self).__init__()
    
    self.input_layer = nn.Linear(input_layers_size, hidden1_layers_size)
    self.hidden1_layers = nn.Linear(hidden1_layers_size, hidden2_layers_size)
    self.hidden2_layers = nn.Linear(hidden2_layers_size, output_layers_size)
    
    self.sigmoid1 = nn.Sigmoid()
    self.sigmoid2 = nn.Sigmoid()


  def forward(self, input):
    out = self.input_layer(input)
    out = self.sigmoid1(out)
    out = self.hidden1_layers(out)
    out = self.sigmoid2(out)
    out = self.hidden2_layers(out)
    return out


  def __normalize(self, data_set):
    __data = data_set.data
    __target = data_set.target
    __min_max_scaler = MinMaxScaler(feature_range=(0, 1))
    

    self.X_train, self.X_test, self.Y_train, self.Y_test = train_test_split(__data, __target)
    X_train_normalized_tensor = torch.tensor(__min_max_scaler.fit_transform(self.X_train), dtype=torch.float32)
    Y_train_normalized_tensor = torch.tensor(self.Y_train, dtype=torch.float32)

    return X_train_normalized_tensor, Y_train_normalized_tensor 

  def learn(self, epochs, data_set, lr, momentum):
    optimizer = optim.SGD(self.parameters(), lr=lr, momentum=momentum)
    criterion = nn.MSELoss()
    self.train()
    X_train_normalized, Y_train_normlized = self.__normalize(data_set=data_set)

    for epoch in range(epochs):
      first_loss = 0.0
      for i in range(0, X_train_normalized.size()[0]):
        optimizer.zero_grad()
        outputs = self.forward(X_train_normalized[i])
        loss = criterion(outputs, Y_train_normlized[i])
        loss.backward()
        optimizer.step()

        first_loss += loss

        if i  == X_train_normalized.size()[0] - 1:
          last_result = f"[{epoch+1}, {i+1}] - {first_loss/X_train_normalized.size()[0]}"
          print(last_result)
          first_loss = 0.0
      
    return last_result

# %%
network = NNIris(4, 100, 50, 3)
network.learn(epochs=100, data_set=iris, lr=0.01, momentum=0.5)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/loss.py:529: UserWarning: Using a target size (torch.Size([])) that is different to the input size (torch.Size([3])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [1, 112] - 0.7741801142692566
# [2, 112] - 0.7245914340019226
# [3, 112] - 0.7121858596801758
# [4, 112] - 0.6994749307632446
# [5, 112] - 0.6858683228492737
# [6, 112] - 0.6707158088684082
# [7, 112] - 0.6532333493232727
# [8, 112] - 0.6324167251586914
# [9, 112] - 0.6069385409355164
# [10, 112] - 0.5750414133071899
# [11, 112] - 0.5344915986061096
# [12, 112] - 0.4827847182750702
# [13, 112] - 0.41803357005119324
# [14, 112] - 0.34106573462486267
# [15, 112] - 0.25828948616981506
# [16, 112] - 0.18209819495677948
# [17, 112] - 0.12491565197706223
# [18, 112] - 0.09077191352844238
# [19, 112] - 0.07445146143436432
# [20, 112] - 0.06802316755056381
# [21, 112] - 0.06584248691797256
# [22, 112] - 0.06513683497905731
# [23, 112] - 0.06483697146177292
# [24, 112] - 0.06460409611463547
# [25, 112] - 0.06435524672269821
# [26, 112] - 0.06408215314149857
# [27, 112] - 0.06379290670156479
# [28, 112] - 0.06349612027406693
# [29, 112] - 0.06319772452116013
# [30, 112] - 0.06290131062269211
# [31, 112] - 0.06260888278484344
# [32, 112] - 0.06232147663831711
# [33, 112] - 0.062039606273174286
# [34, 112] - 0.06176340579986572
# [35, 112] - 0.0614929236471653
# [36, 112] - 0.06122799590229988
# [37, 112] - 0.0609685555100441
# [38, 112] - 0.060714416205883026
# [39, 112] - 0.06046541407704353
# [40, 112] - 0.06022137030959129
# [41, 112] - 0.059982120990753174
# [42, 112] - 0.059747517108917236
# [43, 112] - 0.059517402201890945
# [44, 112] - 0.059291623532772064
# [45, 112] - 0.05907006934285164
# [46, 112] - 0.05885257199406624
# [47, 112] - 0.058639027178287506
# [48, 112] - 0.05842933431267738
# [49, 112] - 0.058223363012075424
# [50, 112] - 0.058021001517772675
# [51, 112] - 0.057822126895189285
# [52, 112] - 0.05762665346264839
# [53, 112] - 0.05743452534079552
# [54, 112] - 0.057245638221502304
# [55, 112] - 0.0570598766207695
# [56, 112] - 0.056877199560403824
# [57, 112] - 0.05669746547937393
# [58, 112] - 0.05652068927884102
# [59, 112] - 0.056346721947193146
# [60, 112] - 0.05617552995681763
# [61, 112] - 0.056007061153650284
# [62, 112] - 0.055841218680143356
# [63, 112] - 0.055677950382232666
# [64, 112] - 0.055517200380563736
# [65, 112] - 0.05535891279578209
# [66, 112] - 0.055203069001436234
# [67, 112] - 0.05504954978823662
# [68, 112] - 0.05489833280444145
# [69, 112] - 0.054749373346567154
# [70, 112] - 0.054602622985839844
# [71, 112] - 0.05445802956819534
# [72, 112] - 0.05431554466485977
# [73, 112] - 0.054175157099962234
# [74, 112] - 0.054036762565374374
# [75, 112] - 0.05390036478638649
# [76, 112] - 0.05376593396067619
# [77, 112] - 0.05363338068127632
# [78, 112] - 0.05350271239876747
# [79, 112] - 0.053373850882053375
# [80, 112] - 0.053246792405843735
# [81, 112] - 0.05312148854136467
# [82, 112] - 0.052997928112745285
# [83, 112] - 0.05287604779005051
# [84, 112] - 0.052755821496248245
# [85, 112] - 0.05263721942901611
# [86, 112] - 0.05252021178603172
# [87, 112] - 0.05240479111671448
# [88, 112] - 0.05229088291525841
# [89, 112] - 0.05217849835753441
# [90, 112] - 0.05206757411360741
# [91, 112] - 0.0519581064581871
# [92, 112] - 0.051850080490112305
# [93, 112] - 0.051743440330028534
# [94, 112] - 0.05163814499974251
# [95, 112] - 0.05153422802686691
# [96, 112] - 0.05143163353204727
# [97, 112] - 0.05133034661412239
# [98, 112] - 0.0512302927672863
# [99, 112] - 0.05113152042031288
# [100, 112] - 0.05103398114442825
# '[100, 112] - 0.05103398114442825'
